# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Projects\\Kidney-Disease-Classification-MLflow-DVC\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Projects\\Kidney-Disease-Classification-MLflow-DVC'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-05-05 01:55:26,761: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-05-05 01:55:26,765: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-05-05 01:55:26,767: INFO: common: created directory at: artifacts]
# [2026-05-05 01:55:26,769: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-05-05 01:55:26,771: INFO: 4142266455: Downloading data from https://drive.google.com/file/d/1MCBDAAN8XOL6IQzCiffLOPUD4FdlLE-i/view?usp=drive_link into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?id=1MCBDAAN8XOL6IQzCiffLOPUD4FdlLE-i
# From (redirected): https://drive.google.com/uc?id=1MCBDAAN8XOL6IQzCiffLOPUD4FdlLE-i&confirm=t&uuid=46f9aa4e-8ad0-40c0-9607-ee1827f0a16c
# To: d:\Projects\Kidney-Disease-Classification-MLflow-DVC\artifacts\data_ingestion\data.zip
#   2%|▏         | 10.5M/575M [00:03<03:02, 3.09MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#       5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
# ----> 7 except Exception as e:
#       8     raise e
#
# Cell In[11], line 23, in DataIngestion.download_file(self)
#      19             gdown.download(prefix+file_id,zip_download_dir)
#      20
#      21             logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")
#      22
# ---> 23         except Exception as e:
#      24             raise e
#
# File d:\Projects\Kidney-Disease-Classification-MLflow-DVC\.venv\Lib\site-packages\gdown\download.py:398, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     396 t_start = time.time()
#     397 downloaded = 0
# --> 398 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     399     f.write(chunk)
#     400     downloaded += len(chunk)
#
# File d:\Projects\Kidney-Disease-Classification-MLflow-DVC\.venv\Lib\site-packages\requests\models.py:822, in Response.iter_content.<locals>.generate()
#     820 if hasattr(self.raw, "stream"):
#     821     try:
# --> 822         yield from self.raw.stream(chunk_size, decode_content=True)
#     823     except ProtocolError as e:
#     824         raise ChunkedEncodingError(e)
#
# File d:\Projects\Kidney-Disease-Classification-MLflow-DVC\.venv\Lib\site-packages\urllib3\response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File d:\Projects\Kidney-Disease-Classification-MLflow-DVC\.venv\Lib\site-packages\urllib3\response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File d:\Projects\Kidney-Disease-Classification-MLflow-DVC\.venv\Lib\site-packages\urllib3\response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)   1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File d:\Projects\Kidney-Disease-Classification-MLflow-DVC\.venv\Lib\site-packages\urllib3\response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
#   2%|▏         | 10.5M/575M [00:20<03:02, 3.09MB/s]
