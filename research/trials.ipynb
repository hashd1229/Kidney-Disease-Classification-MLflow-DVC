# %%
#config box
d = {"key": "val", "key1": "val1"}

# %%
d['key']
# Out:
# 'val'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key": "val", "key1": "val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
#ensure annotatio
